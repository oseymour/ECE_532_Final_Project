# %%
# import packages
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import random
from IPython.display import clear_output

# %%
# import data

# load images
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# vectorize all of the images
x_train = x_train.reshape(-1, 784)
x_test = x_test.reshape(-1, 784)

# convert to black/white
x_train_int = np.array([np.round(image/256) for image in x_train])
x_test_int = np.array([np.round(image/256) for image in x_test])

# %%
# functions for doing k-means on MNIST images

def init_random_centroids(data, k):
    """
    Initialize k random centroids from the given data
    """
    indeces = np.random.choice(data.shape[0], k)
    
    return data[indeces,:]


def init_selected_centroids(data, labels, choices):
    """
    Initialize random centroids from each class (0 thru 9)
    Choices should say how many centroids should be chosen from each class
    """
    assert len(choices) == 10
    
    centroids = []
    
    for y in range(10):
        subset = data[labels == y]
        num = choices[y]
        indeces = []
        for i in range(num):
            index = np.random.choice(subset.shape[0], 1)
            while index in indeces:
                index = np.random.choice(subset.shape[0], 1)
            centroids.append(subset[index,:])
            indeces.append(index)
    
    return np.array(centroids).reshape(len(centroids), 784)

def assign_clusters(data, centroids):
    """
    assign every point in the given data to a centroid
    """
    closest_centroids = []
    for image in data:
        closest = np.argmin([np.linalg.norm(image-centroid) for centroid in centroids])
        closest_centroids.append(closest)

    return np.array(closest_centroids)


def calc_centroid(cluster):
    """
    Calculate the average of all images in the given cluster
    The cluster should be an array of images, with each image in a row
    """
    return np.mean(cluster, axis=0)


def k_means_mnist(data, k, max_iters=10, init_method='random', choices=None, labels=None):
    """
    Apply the given helper functions to find the k centroids
    """
    # initialize the centroids
    if init_method == 'random':
        centroids = init_random_centroids(data, k)
    elif init_method == 'selected':
        assert np.sum(choices) == k
        centroids = init_selected_centroids(data, labels, choices)
    
    # iteratively move the centroids
    for it in range(max_iters):
           
        new_centroids = np.empty([k,784])

        for i in range(k):
            print('Currently on centroid', i+1, 'of', k, 'and iteration', it+1, 'out of', max_iters)
            closest = assign_clusters(data, centroids)
            
            cluster = data[closest==i]
            
            new_centroids[i] = calc_centroid(cluster)
            
            clear_output()

        centroids = new_centroids
    
    return centroids

# %% [markdown]
# # 10 random clusters

# %%
# get centroids
centroids = k_means_mnist(x_train, 10)

# %%
# display the centroids
for i in range(len(centroids)):
    plt.imshow(centroids[i].reshape(28,28))
    plt.show()

# %%
# label the clusters by hand
labels = [4,6,3,1,1,9,0,6,8,7]
assert len(labels) == len(centroids)

# calculate error rate
yhat = []
for x in x_test:
    index = np.argmin(([np.linalg.norm(x - centroid) for centroid in centroids]))
    yhat.append(labels[index])
assert len(yhat) == len(y_test)
errors = np.sum(yhat != y_test)
print('Error rate =', errors/len(y_test))
# Out:
# Error rate = 0.4431

# %% [markdown]
# # 20 random clusters

# %%
# get centroids
centroids = k_means_mnist(x_train, 20)

# %%
# display the centroids
for i in range(len(centroids)):
    plt.imshow(centroids[i].reshape(28,28))
    plt.show()

# %%
# label the clusters by hand
labels = [0,3,3,4,7,0,1,2,8,9,5,9,2,6,9,1,7,4,3,6]
assert len(labels) == len(centroids)

# calculate error rate
yhat = []
for x in x_test:
    index = np.argmin(([np.linalg.norm(x - centroid) for centroid in centroids]))
    yhat.append(labels[index])
assert len(yhat) == len(y_test)
errors = np.sum(yhat != y_test)
print('Error rate =', errors/len(y_test))
# Out:
# Error rate = 0.3019

# %% [markdown]
# # 10 clusters, with one chosen from each class

# %%
choices = np.array([
    1, # 1 zero
    1, # 1 one
    1, # 1 two
    1, # 1 three
    1, # 1 four
    1, # 1 five
    1, # 1 six
    1, # 1 seven
    1, # 1 eight
    1, # 1 nine
])
centroids = k_means_mnist(x_train, 10, init_method='selected', choices=choices, labels=y_train)

# %%
# display the centroids
for i in range(len(centroids)):
    plt.imshow(centroids[i].reshape(28,28))
    plt.show()

# %%
# label the clusters by hand
labels = [8, 1, 2, 3, 4, 0, 6, 7, 3, 9]
assert len(labels) == len(centroids)

# calculate error rate
yhat = []
for x in x_test:
    index = np.argmin(([np.linalg.norm(x - centroid) for centroid in centroids]))
    yhat.append(labels[index])
assert len(yhat) == len(y_test)
errors = np.sum(yhat != y_test)
print('Error rate =', errors/len(y_test))
# Out:
# Error rate = 0.3888

# %% [markdown]
# ## 20 clusters, with various numbers chosen from each class

# %%
choices = np.array([
    2, # 1 zero
    1, # 1 one
    1, # 1 two
    1, # 1 three
    1, # 1 four
    3, # 1 five
    3, # 1 six
    3, # 1 seven
    4, # 1 eight
    1, # 1 nine
])
centroids = k_means_mnist(x_train, 20, init_method='selected', choices=choices, labels=y_train)

# %%
# display the centroids
for i in range(len(centroids)):
    plt.imshow(centroids[i].reshape(28,28))
    plt.show()

# %%
# label the clusters by hand
labels = [0,0,1,2,3,4,5,1,5,6,6,6,7,1,7,3,8,8,5,9,]
assert len(labels) == len(centroids)

# calculate error rate
yhat = []
for x in x_test:
    index = np.argmin(([np.linalg.norm(x - centroid) for centroid in centroids]))
    yhat.append(labels[index])
assert len(yhat) == len(y_test)
errors = np.sum(yhat != y_test)
print('Error rate =', errors/len(y_test))
# Out:
# Error rate = 0.2994

# %% [markdown]
# # Singular values for square images

# %%
# x_train_adj = (x_train - np.mean(x_train, axis=0)).reshape(60000,28,28)
# U, s, VT = np.linalg.svd(x_train_adj, full_matrices = False)
# print(U.shape)
# print(s.shape)
# print(VT.shape)

# s_all = np.mean(s, axis=0)
# plt.plot(np.log(s_all))
# plt.axhline(0)
# plt.show()

# x_train_pca = np.empty([60000,28,28])
# for i in range(x_train_adj.shape[0]):
#     x_train_pca[i] = U[i,:,:19] @ np.diag(s[i,:19]) @ VT[i,:19,:]
# x_train_pca = x_train_pca.reshape(60000,784)

# # the initial ten centroids are randomly chosen from x_train
# # centroids = x_train_pca[np.random.choice(len(x_train), 10)]

# # the initial ten centroids are the first occurence of each number in x_train
# centroids = x_train_pca[[1, 3, 5, 7, 2, 0, 13, 15, 17, 4]]

# og_centroids = centroids
# new_centroids = np.empty([10,784])

# for iters in range(10):
#     # determine nearest centroid for each image in x_train
#     closest = np.array([np.argmin([np.linalg.norm(x-centroid) for centroid in centroids]) for x in x_train_pca])

#     # update the centroids
#     for k in range(10):
#         cluster = x_train_pca[closest==k]
#         new_centroids[k] = np.mean(cluster, axis=0)
#     centroids = new_centroids

# for i in range(10):
#     plt.imshow(centroids[i].reshape(28,28))
#     plt.show()

# x_test_adj = (x_test - np.mean(x_test, axis=0)).reshape(10000,28,28)
# U, s, VT = np.linalg.svd(x_test_adj, full_matrices = False)
# print(U.shape)
# print(s.shape)
# print(VT.shape)

# s_all = np.mean(s, axis=0)
# plt.plot(np.log(s_all))
# plt.axhline(0)
# plt.show()

# x_test_pca = np.empty([10000,28,28])
# for i in range(x_test_adj.shape[0]):
#     x_test_pca[i] = U[i,:,:19] @ np.diag(s[i,:19]) @ VT[i,:19,:]
# x_test_pca = x_test_pca.reshape(10000,784)

# y_hat = np.array([np.argmin([np.linalg.norm(x-centroid) for centroid in centroids]) for x in x_test_pca])
# print('error:', np.sum(y_hat!=y_test)/y_test.shape[0])

# %% [markdown]
# # Singular values for vectorized images

# %%
# x_train_adj = (x_train - np.mean(x_train, axis=0))
# U, s, VT = np.linalg.svd(x_train_adj, full_matrices = False)
# print(U.shape)
# print(s.shape)
# print(VT.shape)

# plt.plot(np.log(s))
# plt.show()

# x_train_pca = np.empty([60000,784])
# for i in range(x_train_adj.shape[0]):
#     x_train_pca[i] = U[i,:712] @ np.diag(s[:712]) @ VT[:712,:]

# # the initial ten centroids are randomly chosen from x_train
# # centroids = x_train_pca[np.random.choice(len(x_train), 10)]

# # the initial ten centroids are the first occurence of each number in x_train
# centroids = x_train_pca[[1, 3, 5, 7, 2, 0, 13, 15, 17, 4]]

# og_centroids = centroids
# new_centroids = np.empty([10,784])

# for iters in range(10):
#     # determine nearest centroid for each image in x_train
#     closest = np.array([np.argmin([np.linalg.norm(x-centroid) for centroid in centroids]) for x in x_train_pca])

#     # update the centroids
#     for k in range(10):
#         cluster = x_train_pca[closest==k]
#         new_centroids[k] = np.mean(cluster, axis=0)
#     centroids = new_centroids

# for i in range(10):
#     plt.imshow(centroids[i].reshape(28,28))
#     plt.show()

# x_test_adj = (x_test - np.mean(x_test, axis=0))
# U, s, VT = np.linalg.svd(x_test_adj, full_matrices = False)
# print(U.shape)
# print(s.shape)
# print(VT.shape)

# plt.plot(np.log(s))
# plt.show()

# x_test_pca = np.empty([10000,784])
# for i in range(x_test_adj.shape[0]):
#     x_test_pca[i] = U[i,:712] @ np.diag(s[:712]) @ VT[:712,:]

# y_hat = np.array([np.argmin([np.linalg.norm(x-centroid) for centroid in centroids]) for x in x_test_pca])
# print('error:', np.sum(y_hat!=y_test)/y_test.shape[0])

# %% [markdown]
# # Singular values for transposed vectorized images

# %%
# x_train_adj = (x_train - np.mean(x_train, axis=0)).reshape(60000,784).T
# U, s, VT = np.linalg.svd(x_train_adj, full_matrices = False)
# print(U.shape)
# print(s.shape)
# print(VT.shape)

# plt.plot(np.log(s))
# plt.show()

# x_train_pca = np.empty([784,60000])
# for i in range(x_train_adj.shape[0]):
#     x_train_pca[i] = U[i,:712] @ np.diag(s[:712]) @ VT[:712,:]

# # the initial ten centroids are randomly chosen from x_train
# # centroids = x_train_pca[np.random.choice(len(x_train), 10)]

# # the initial ten centroids are the first occurence of each number in x_train
# centroids = x_train_pca[[1, 3, 5, 7, 2, 0, 13, 15, 17, 4]]

# og_centroids = centroids
# new_centroids = np.empty([784,10])

# for iters in range(10):
#     # determine nearest centroid for each image in x_train
#     closest = np.array([np.argmin([np.linalg.norm(x-centroid) for centroid in centroids]) for x in x_train_pca])

#     # update the centroids
#     for k in range(10):
#         cluster = x_train_pca[closest==k]
#         new_centroids[k] = np.mean(cluster, axis=0)
#     centroids = new_centroids

# for i in range(10):
#     plt.imshow(centroids[i].reshape(28,28))
#     plt.show()

# x_test_adj = (x_test - np.mean(x_test, axis=0)).reshape(10000,784).T
# U, s, VT = np.linalg.svd(x_adj, full_matrices = False)
# print(U.shape)
# print(s.shape)
# print(VT.shape)

# plt.plot(np.log(s))
# plt.show()

# x_test_pca = np.empty([784,10000])
# for i in range(x_test_adj.shape[0]):
#     x_test_pca[i] = U[i,:712] @ np.diag(s[:712]) @ VT[:712,:]

# y_hat = np.array([np.argmin([np.linalg.norm(x-centroid) for centroid in centroids]) for x in x_test_pca])
# print('error:', np.sum(y_hat!=y_test)/y_test.shape[0])
